# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pymc3 as pm
import scipy.io
import scipy as sp
import theano.tensor as th

# %%
# lets create a unit circle and a cross
phi2 = np.linspace(0,2*np.pi,360)
x_circle2 = np.cos(phi)
y_circle2 = np.sin(phi)
phi_hor2 = 0
phi_vert2 = np.pi/2
r2 = np.linspace(-1,1,100)
x_hor2 = r*np.cos(phi_hor)
y_hor2 = r*np.sin(phi_hor)
x_vert2 = r*np.cos(phi_vert)
y_vert2 = r*np.sin(phi_vert)

# %%
plt.axes().set_aspect('equal', 'datalim')
plt.scatter(x_circle,y_circle,marker = ".",s=2)
plt.scatter(x_hor,y_hor,marker = ".",s=2)
plt.scatter(x_vert,y_vert,marker = ".",s=2)

# %%
# lets create a distorted cross
# both horizontal lines are 
phi_rotate = np.pi/8
phi2 = np.linspace(0,2*np.pi,360)
x_circle2 = np.cos(phi)
y_circle2 = np.sin(phi)


plt.axes().set_aspect('equal', 'datalim')
plt.scatter(x_circle2,y_circle2,marker = ".",s=2)
plt.scatter(x_hor2,y_hor2,marker = ".",s=2,label="hor")
plt.scatter(x_vert2,y_vert2,marker = ".",s=2,label="vert")
plt.legend()
